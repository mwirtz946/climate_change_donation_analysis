# %% [markdown]
# # Imports

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import classification_report, plot_confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import ComplementNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics import recall_score, accuracy_score, f1_score
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from xgboost import XGBClassifier

import gensim
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import warnings
# %matplotlib inline
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 1000)

# %%
data = pd.read_csv('./data_collection/prepared_twitter_sentiment_data.csv', index_col=0)

# %%
# Drop 31 rows with missing message column
data.dropna(inplace=True)

# %%
# Reassigning target variable names to exclude -1
data.sentiment = data.sentiment.apply(lambda x: 'anti' if x == -1 else x)
data.sentiment = data.sentiment.apply(lambda x: 'neutral' if x == 0 else x)
data.sentiment = data.sentiment.apply(lambda x: 'man' if x == 1 else x)
data.sentiment = data.sentiment.apply(lambda x: 'news' if x == 2 else x)

# %% [markdown]
# # Data Prep

# %% [markdown]
# ## Unigram TF-IDF Vectorizer

# %%
X = data.drop(columns = 'sentiment')
y = data.sentiment

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.20, 
                                                    random_state=1)

# %%
# Instantiate vectorizer
tfidf = TfidfVectorizer(ngram_range= (1,1))
# Fit to training data
tfidf_train = tfidf.fit_transform(X_train.message)
# Transform test data
tfidf_test = tfidf.transform(X_test.message)

# %%
# Convert vectors to dataframe
tfidf_train_df = pd.DataFrame.sparse.from_spmatrix(
    tfidf_train, columns=tfidf.get_feature_names())
tfidf_test_df = pd.DataFrame.sparse.from_spmatrix(
    tfidf_test, columns=tfidf.get_feature_names())

# %% [markdown]
# ## Adding Engineered Features

# %%
# Extracting just features from dataframe
tfidf_train_features = X_train.drop(columns='message')
tfidf_test_features = X_test.drop(columns='message')

# Reset index to match tfidf dataframe
tfidf_train_features.reset_index(drop=True, inplace=True)
tfidf_test_features.reset_index(drop=True, inplace=True)

# %%
# Combining tfidf with custom features
tfidf_train_featured = tfidf_train_df.join(tfidf_train_features, how='outer')
tfidf_test_featured = tfidf_test_df.join(tfidf_test_features, how='outer')

# %% [markdown]
# ## Doc2Vec

# %%
# Performing train test split including target variable
train, test = train_test_split(data, test_size=0.2, random_state=42)

# %%
# Separating target variables from train and test
y_train_doc = train.sentiment
y_test_doc = test.sentiment

# %%
# Tokenizing and tagging each observation message column
train_docs = train.apply(lambda x: TaggedDocument(words=x.message.split(), tags=[x.sentiment]), axis=1)

# %%
# Tokenizing train and test data
train_data = [tweet.split() for tweet in train['message']]
test_data = [tweet.split() for tweet in test['message']]

# %%
# %%time

# training Doc2Vec
model = Doc2Vec(vector_size=10, 
                alpha=0.025, 
                min_count=5,
                epochs=100)

model.build_vocab(train_docs)
model.train(train_docs, 
            total_examples=model.corpus_count, 
            epochs=model.epochs)
# Out:
# CPU times: user 3min 5s, sys: 37.6 s, total: 3min 43s
# Wall time: 2min 54s

# %%
# %%time

# infer in multiple steps to get a stable representation 
train_vecs = [model.infer_vector(words, epochs=100) \
              for words in train_data]
test_vecs = [model.infer_vector(words, epochs=100) \
             for words in test_data]
# Out:
# CPU times: user 2min 27s, sys: 1.58 s, total: 2min 28s
# Wall time: 2min 37s

# %%
# %%time

# convert both sets to dataframe
doc_train_df = pd.DataFrame(train_vecs, columns=[
    f'docvec_{i}' for i in range(1,11)
])

doc_test_df = pd.DataFrame(test_vecs, columns=[
    f'docvec_{i}' for i in range(1,11)
])
# Out:
# CPU times: user 139 ms, sys: 10.5 ms, total: 150 ms
# Wall time: 182 ms

# %% [markdown]
# ### Adding Engineered Features

# %%
# Extracting just features from dataframe
train_features = train.drop(columns=['sentiment','message'])
test_features = test.drop(columns=['sentiment','message'])

# Reset index to match doc2vec dataframe
train_features.reset_index(drop=True, inplace=True)
test_features.reset_index(drop=True, inplace=True)

# %%
# Combining Doc2Vec with custom features
doc_train_featured = doc_train_df.join(train_features, how='outer')
doc_test_featured = doc_test_df.join(test_features, how='outer')

# %% [markdown]
# # Choosing Best Model

# %% [markdown]
# ## Unigram TF-IDF Vectorizer

# %% [markdown]
# ### Without Features Added

# %% [markdown]
# #### Random Forest

# %%
# Instantiate Classifier
rf_tfidf = RandomForestClassifier()
# Fit to training data
rf_tfidf.fit(tfidf_train_df, y_train)
# Predict on testing data
rf_tfidf_preds = rf_tfidf.predict(tfidf_test_df)
# Evaluating with classification report
print(classification_report(y_test, rf_tfidf_preds))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.78      0.32      0.45       823
#          man       0.68      0.89      0.77      4526
#      neutral       0.59      0.37      0.46      1549
#         news       0.75      0.60      0.67      1885
#
#     accuracy                           0.68      8783
#    macro avg       0.70      0.55      0.59      8783
# weighted avg       0.69      0.68      0.66      8783

# %% [markdown]
# #### SVM

# %%
tfidf_train_df=tfidf_train_df.to_numpy()
tfidf_test_df=tfidf_test_df.to_numpy()

# %%
# Instantiate Classifier
svm_tfidf = svm.SVC(decision_function_shape='ovr', gamma = 'auto')
# Fit to training data
svm_tfidf.fit(tfidf_train_df, y_train)
# Predict on testing data
svm_tfidf_preds = svm_tfidf.predict(tfidf_test_df)
# Evaluating with classification report
print(classification_report(y_test, svm_tfidf_preds))

# %% [markdown]
# #### Logistic Regression

# %%
# Instantiate Classifier
lr_tfidf = LogisticRegression()
# Fit to training data
lr_tfidf.fit(tfidf_train_df, y_train)
# Predict on testing data
lr_tfidf_preds = lr_tfidf.predict(tfidf_test_df)
# Evaluating with classification report
print(classification_report(y_test, lr_tfidf_preds))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.73      0.41      0.52       823
#          man       0.71      0.87      0.78      4526
#      neutral       0.63      0.43      0.51      1549
#         news       0.73      0.66      0.69      1885
#
#     accuracy                           0.70      8783
#    macro avg       0.70      0.59      0.63      8783
# weighted avg       0.70      0.70      0.69      8783

# %% [markdown]
# #### Multinomial Naive Bayes

# %%
# Instantiate Classifier
mnb_tfidf = MultinomialNB()
# Fit to training data
mnb_tfidf.fit(tfidf_train_df, y_train)
# Predict on testing data
mnb_tfidf_preds = mnb_tfidf.predict(tfidf_test_df)
# Evaluating with classification report
print(classification_report(y_test, mnb_tfidf_preds))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.91      0.06      0.12       823
#          man       0.58      0.98      0.73      4526
#      neutral       0.84      0.08      0.15      1549
#         news       0.82      0.39      0.53      1885
#
#     accuracy                           0.61      8783
#    macro avg       0.79      0.38      0.38      8783
# weighted avg       0.71      0.61      0.52      8783

# %%
print(f1_score(y_test, mnb_tfidf_preds, average='micro'))
# Out:
# 0.6079927131959467

# %% [markdown]
# #### Complement Naive Bayes

# %%
# Instantiate Classifier
cnb_tfidf = ComplementNB()
# Fit to training data
cnb_tfidf.fit(tfidf_train_df, y_train)
# Predict on testing data
cnb_tfidf_preds = cnb_tfidf.predict(tfidf_test_df)
# Evaluating with classification report
print(classification_report(y_test, cnb_tfidf_preds))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.57      0.47      0.51       823
#          man       0.73      0.80      0.76      4526
#      neutral       0.60      0.36      0.45      1549
#         news       0.63      0.73      0.67      1885
#
#     accuracy                           0.68      8783
#    macro avg       0.63      0.59      0.60      8783
# weighted avg       0.67      0.68      0.67      8783

# %% [markdown]
# #### Bernoulli Naive Bayes

# %%
# Instantiate Classifier
bnb_tfidf = BernoulliNB()
# Fit to training data
bnb_tfidf.fit(tfidf_train_df, y_train)
# Predict on testing data
bnb_tfidf_preds = bnb_tfidf.predict(tfidf_test_df)
# Evaluating with classification report
print(classification_report(y_test, bnb_tfidf_preds))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.75      0.24      0.36       823
#          man       0.67      0.85      0.75      4526
#      neutral       0.53      0.39      0.45      1549
#         news       0.71      0.62      0.66      1885
#
#     accuracy                           0.66      8783
#    macro avg       0.67      0.53      0.56      8783
# weighted avg       0.66      0.66      0.64      8783

# %% [markdown]
# #### XGBoost

# %%
tfidf_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35129 entries, 0 to 35128
# Columns: 23251 entries, aaa to zzzzzz
# dtypes: Sparse[float64, 0.0](23251)
# memory usage: 3.8 MB

# %%
# Instantiate Classifier
xgboost_tfidf = XGBClassifier()
# Fit to training data
xgboost_tfidf.fit(tfidf_train_df, y_train)
# Predict on testing data
xgboost_tfidf_preds = xgboost_tfidf.predict(tfidf_test_df)
# Evaluating with classification report
print(classification_report(y_test, xgboost_tfidf_preds))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-69efe28aa563> in <module>
#       2 xgboost_tfidf = XGBClassifier()
#       3 # Fit to training data
# ----> 4 xgboost_tfidf.fit(tfidf_train_df, y_train)
#       5 # Predict on testing data
#       6 xgboost_tfidf_preds = xgboost_tfidf.predict(tfidf_test_df)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     724         else:
#     725             train_dmatrix = DMatrix(X, label=training_labels,
# --> 726                                     missing=self.missing, nthread=self.n_jobs)
#     727
#     728         self._Booster = train(xgb_options, train_dmatrix, self.get_num_boosting_rounds(),
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/xgboost/core.py in __init__(self, data, label, missing, weight, silent, feature_names, feature_types, nthread)
#     378         data, feature_names, feature_types = _maybe_pandas_data(data,
#     379                                                                 feature_names,
# --> 380                                                                 feature_types)
#     381
#     382         data, feature_names, feature_types = _maybe_dt_data(data,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/xgboost/core.py in _maybe_pandas_data(data, feature_names, feature_types)
#     237         msg = """DataFrame.dtypes for data must be int, float or bool.
#     238                 Did not expect the data types in fields """
# --> 239         raise ValueError(msg + ', '.join(bad_fields))
#     240
#     241     if feature_names is None:
#
# ValueError: DataFrame.dtypes for data must be int, float or bool.
#                 Did not expect the data types in fields aaa, aaaaaaaaa, aaaaaaaaaaa, aaaaaaaaaaaaaaaaaaaah, aaaaaand, aaaaand, aaaand, aag, aai, aan, aap, aardig, aarey, aarne, aaron, aba, ababa, abaixo, abandon, abandond, abandoned, abandoning, abate, abated, abatement, abbas, abbot, abbott, abc, abclimate, abcnews, abctv, abcxyz, abdah, abdic, abdicate, aber, aberdee, aberdeenshire, aberrant, aberration, abhorrent, abide, abiding, abigail, ability, abisko, able, ableg, abndp, abnormal, abnormally, abo, aboard, abolish, abolished, abolishes, abolishing, abolition, abominable, aboriginal, aborted, abortion, abortionis, abortionist, abou, abounds, abpoli, abraham, abri, abroad, abrogate, abrupt, abruptly, abscbnnews, absence, absent, absol, absolu, absolute, absolutel, absolutely, absolutley, absorb, absorbed, absorbing, absorbs, abstract, abstraction, absurd, absurdity, abt, abtns, abuja, abund, abundantly, abuse, abused, abusing, abut, abysmal, abyss, aca, academi, academia, academic, academician, academy, acc, acccords, acce, accele, accelerant, accelerate, accelerated, accelerates, accelerating, acceleration, accelerator, accellerates, accent, accept, acceptable, acceptance, accepted, accepter, accepting, acceptor, accepts, access, accessibility, accessible, accessing, accession, acci, accident, accidental, accidentally, acciona, acclaimed, accom, accomplice, accomplish, accomplishment, accord, accordi, accordin, according, accordingly, accordodiparigi, accou, account, accountability, accountabl, accountable, accountant, accounting, acct, acctually, accu, accumulation, accuracy, accurate, accurately, accusation, accuse, accused, accuses, accusing, accustomed, accuweather, acha, acharya, ache, achedin, achievable, achieve, achieved, achievement, achieving, acia, acid, acidic, acidification, acidifying, acidity, ack, ackley, ackn, acknowledge, acknowledged, acknowledgement, acknowledges, acknowledging, acknowleding, ackroyd, acne, acolyte, acontecendo, acording, acorn, acostta, acp, acqua, acquisition, acr, acre, acrid, acropolis, across, acrylic, acsp, act, acted, acti, acting, actio, action, actionaid, actionnewsoffice, actionsforclimate, actiontime, activate, activates, active, actively, activi, activism, activist, activista, activit, activity, actng, acto, actoncl, actoncli, actonclim, actonclima, actonclimat, actonclimate, actor, actual, actuallivingscientist, actually, actuary, actus, acu, acuerdo, acumen, acute, acwknowledges, ada, adalah, adam, adani, adanimineenvironmentaldisaster, adapation, adapt, adapta, adaptable, adaptaion, adaptation, adapted, adapting, adaption, adaptive, adattarsi, adb, add, added, addendum, adderall, addict, addiction, adding, addio, addis, addition, additional, addled, addresed, address, addressed, addressing, adekunle, adelai, adelaide, adelaidestorm, adelson, adepten, adequate, adequately, adesina, adhere, adherent, adi, aditya, adjust, adjusted, adjuster, adjusting, adjustment, adlay, adm, admin, admini, adminis, administation, administr, administra, administrat, administration, administrative, administrator, admirable, admiral, admire, admission, admit, admits, admitted, admitting, ado, adoftheday, adopt, adopted, adopting, adoption, adoptionug, adopts, adorable, adp, adrean, adresse, adriatic, adrift, adsw, adua, adulates, adult, adultery, advance, advanced, advancement, advancing, advani, advantage, adventure, adventurer, adventurism, adversary, adverse, adversely, advert, advertised, advertising, advice, advise, advised, adviser, advises, advising, advisor, advisory, advoca, advocacy, advocate, advocatestree, advocating, adw, adwords, adzuchangingtimes, aec, aedes, aef, aegypti, aehhumm, aei, aerial, aerosol, aerospace, aesthetic, afcofficial, afdb, aff, affair, affe, affec, affect, affected, affecting, affectionate, affectof, afferma, affiliate, affinity, affirm, affirmed, affirms, afflicting, affliction, afford, affordability, affordable, afforestation, affront, afghanistan, afined ...

# %% [markdown]
# ### With Features Added

# %% [markdown]
# #### Random Forest

# %%
# Instantiate Classifier
rf_tfidf_featured = RandomForestClassifier()
# Fit to training data
rf_tfidf_featured.fit(tfidf_train_featured, y_train)
# Predict on testing data
rf_tfidf_featured_preds = rf_tfidf_featured.predict(tfidf_test_featured)
# Evaluating with classification report
print(classification_report(y_test, rf_tfidf_featured_preds))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.89      0.19      0.31       823
#          man       0.65      0.93      0.77      4526
#      neutral       0.71      0.34      0.46      1549
#         news       0.81      0.61      0.70      1885
#
#     accuracy                           0.69      8783
#    macro avg       0.76      0.52      0.56      8783
# weighted avg       0.72      0.69      0.66      8783

# %% [markdown]
# #### SVM

# %%
# Instantiate Classifier
svm_tfidf_featured = svm.SVC()
# Fit to training data
svm_tfidf_featured.fit(tfidf_train_featured, y_train)
# Predict on testing data
svm_tfidf_featured_preds = svm_tfidf_featured.predict(tfidf_test_featured)
# Evaluating with classification report
print(classification_report(y_test, svm_tfidf_featured_preds))

# %% [markdown]
# #### Logistic Regression

# %%
# Instantiate Classifier
lr_tfidf_featured = LogisticRegression()
# Fit to training data
lr_tfidf_featured.fit(tfidf_train_featured, y_train)
# Predict on testing data
lr_tfidf_featured_preds = lr_tfidf_featured.predict(tfidf_test_featured)
# Evaluating with classification report
print(classification_report(y_test, lr_tfidf_featured_preds))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.43      0.01      0.01       823
#          man       0.59      0.86      0.70      4526
#      neutral       0.54      0.19      0.28      1549
#         news       0.51      0.45      0.48      1885
#
#     accuracy                           0.57      8783
#    macro avg       0.52      0.38      0.37      8783
# weighted avg       0.55      0.57      0.52      8783

# %% [markdown]
# #### Multinomial Naive Bayes

# %%
# Instantiate Classifier
mnb_tfidf_featured = MultinomialNB()
# Fit to training data
mnb_tfidf_featured.fit(tfidf_train_featured, y_train)
# Predict on testing data
mnb_tfidf_featured_preds = mnb_tfidf_featured.predict(tfidf_test_featured)
# Evaluating with classification report
print(classification_report(y_test, mnb_tfidf_featured_preds))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-232b4a4167ec> in <module>
#       2 mnb_tfidf_featured = MultinomialNB()
#       3 # Fit to training data
# ----> 4 mnb_tfidf_featured.fit(tfidf_train_featured, y_train)
#       5 # Predict on testing data
#       6 mnb_tfidf_featured_preds = mnb_tfidf_featured.predict(tfidf_test_featured)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     613         self : object
#     614         """
# --> 615         X, y = self._check_X_y(X, y)
#     616         _, n_features = X.shape
#     617         self.n_features_ = n_features
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/naive_bayes.py in _check_X_y(self, X, y)
#     478
#     479     def _check_X_y(self, X, y):
# --> 480         return self._validate_data(X, y, accept_sparse='csr')
#     481
#     482     def _update_class_log_prior(self, class_prior=None):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     800                     ensure_min_samples=ensure_min_samples,
#     801                     ensure_min_features=ensure_min_features,
# --> 802                     estimator=estimator)
#     803     if multi_output:
#     804         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     636         # make sure we actually converted to numeric:
#     637         if dtype_numeric and array.dtype.kind == "O":
# --> 638             array = array.astype(np.float64)
#     639         if not allow_nd and array.ndim >= 3:
#     640             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# KeyboardInterrupt:

# %% [markdown]
# #### Complement Naive Bayes

# %%
# Instantiate Classifier
cnb_tfidf_featured = ComplementNB()
# Fit to training data
cnb_tfidf_featured.fit(tfidf_train_featured, y_train)
# Predict on testing data
cnb_tfidf_featured_preds = cnb_tfidf_featured.predict(tfidf_test_featured)
# Evaluating with classification report
print(classification_report(y_test, cnb_tfidf_featured_preds))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-be2157e2bbe4> in <module>
#       2 cnb_tfidf_featured = ComplementNB()
#       3 # Fit to training data
# ----> 4 cnb_tfidf_featured.fit(tfidf_train_featured, y_train)
#       5 # Predict on testing data
#       6 cnb_tfidf_featured_preds = cnb_tfidf_featured.predict(tfidf_test_featured)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     639
#     640         self._init_counters(n_effective_classes, n_features)
# --> 641         self._count(X, Y)
#     642         alpha = self._check_alpha()
#     643         self._update_feature_log_prob(alpha)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/naive_bayes.py in _count(self, X, Y)
#     868     def _count(self, X, Y):
#     869         """Count feature occurrences."""
# --> 870         check_non_negative(X, "ComplementNB (input X)")
#     871         self.feature_count_ += safe_sparse_dot(Y.T, X)
#     872         self.class_count_ += Y.sum(axis=0)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/validation.py in check_non_negative(X, whom)
#    1044
#    1045     if X_min < 0:
# -> 1046         raise ValueError("Negative values in data passed to %s" % whom)
#    1047
#    1048
#
# ValueError: Negative values in data passed to ComplementNB (input X)

# %% [markdown]
# #### Bernoulli Naive Bayes

# %%
# Instantiate Classifier
bnb_tfidf_featured = BernoulliNB()
# Fit to training data
bnb_tfidf_featured.fit(tfidf_train_featured, y_train)
# Predict on testing data
bnb_tfidf_featured_preds = bnb_tfidf_featured.predict(tfidf_test_featured)
# Evaluating with classification report
print(classification_report(y_test, bnb_tfidf_featured_preds))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.76      0.26      0.38       823
#          man       0.70      0.84      0.76      4526
#      neutral       0.54      0.42      0.47      1549
#         news       0.70      0.70      0.70      1885
#
#     accuracy                           0.68      8783
#    macro avg       0.68      0.55      0.58      8783
# weighted avg       0.68      0.68      0.66      8783

# %% [markdown]
# ## Doc2Vec

# %% [markdown]
# ### Without Features Added

# %% [markdown]
# #### Random Forest

# %%
# Instantiate Classifier
rf_doc = RandomForestClassifier()
# Fit to training data
rf_doc.fit(doc_train_df, y_train_doc)
# Predict on testing data
rf_doc_preds = rf_doc.predict(doc_test_df)
# Evaluating with classification report
print(classification_report(y_test_doc, rf_doc_preds))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.60      0.42      0.49       785
#          man       0.70      0.81      0.75      4529
#      neutral       0.48      0.40      0.44      1562
#         news       0.69      0.62      0.65      1907
#
#     accuracy                           0.66      8783
#    macro avg       0.62      0.56      0.58      8783
# weighted avg       0.65      0.66      0.65      8783

# %% [markdown]
# #### SVM

# %% [markdown]
# #### Logistic Regression

# %%
# Instantiate Classifier
lr_doc = LogisticRegression()
# Fit to training data
lr_doc.fit(doc_train_df, y_train_doc)
# Predict on testing data
lr_doc_preds = lr_doc.predict(doc_test_df)
# Evaluating with classification report
print(classification_report(y_test_doc, lr_doc_preds))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.54      0.43      0.48       785
#          man       0.68      0.77      0.72      4529
#      neutral       0.44      0.36      0.39      1562
#         news       0.64      0.60      0.62      1907
#
#     accuracy                           0.63      8783
#    macro avg       0.57      0.54      0.55      8783
# weighted avg       0.62      0.63      0.62      8783

# %% [markdown]
# #### Multinomial Naive Bayes

# %%
# Instantiate Classifier
mnb_doc = MultinomialNB()
# Fit to training data
mnb_doc.fit(doc_train_df, y_train_doc)
# Predict on testing data
mnb_doc_preds = mnb_doc.predict(doc_test_df)
# Evaluating with classification report
print(classification_report(y_test_doc, mnb_doc_preds))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-e63f57d6939d> in <module>
#       2 mnb_doc = MultinomialNB()
#       3 # Fit to training data
# ----> 4 mnb_doc.fit(doc_train_df, y_train_doc)
#       5 # Predict on testing data
#       6 mnb_doc_preds = mnb_doc.predict(doc_test_df)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     639
#     640         self._init_counters(n_effective_classes, n_features)
# --> 641         self._count(X, Y)
#     642         alpha = self._check_alpha()
#     643         self._update_feature_log_prob(alpha)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/naive_bayes.py in _count(self, X, Y)
#     761     def _count(self, X, Y):
#     762         """Count and smooth feature occurrences."""
# --> 763         check_non_negative(X, "MultinomialNB (input X)")
#     764         self.feature_count_ += safe_sparse_dot(Y.T, X)
#     765         self.class_count_ += Y.sum(axis=0)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/validation.py in check_non_negative(X, whom)
#    1044
#    1045     if X_min < 0:
# -> 1046         raise ValueError("Negative values in data passed to %s" % whom)
#    1047
#    1048
#
# ValueError: Negative values in data passed to MultinomialNB (input X)

# %% [markdown]
# #### Complement Naive Bayes

# %%
# Instantiate Classifier
cnb_doc = ComplementNB()
# Fit to training data
cnb_doc.fit(doc_train_df, y_train_doc)
# Predict on testing data
cnb_doc_preds = cnb_doc.predict(doc_test_df)
# Evaluating with classification report
print(classification_report(y_test_doc, cnb_doc_preds))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-6358c57b8d0a> in <module>
#       2 cnb_doc = ComplementNB()
#       3 # Fit to training data
# ----> 4 cnb_doc.fit(doc_train_df, y_train_doc)
#       5 # Predict on testing data
#       6 cnb_doc_preds = cnb_doc.predict(doc_test_df)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     639
#     640         self._init_counters(n_effective_classes, n_features)
# --> 641         self._count(X, Y)
#     642         alpha = self._check_alpha()
#     643         self._update_feature_log_prob(alpha)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/naive_bayes.py in _count(self, X, Y)
#     868     def _count(self, X, Y):
#     869         """Count feature occurrences."""
# --> 870         check_non_negative(X, "ComplementNB (input X)")
#     871         self.feature_count_ += safe_sparse_dot(Y.T, X)
#     872         self.class_count_ += Y.sum(axis=0)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/validation.py in check_non_negative(X, whom)
#    1044
#    1045     if X_min < 0:
# -> 1046         raise ValueError("Negative values in data passed to %s" % whom)
#    1047
#    1048
#
# ValueError: Negative values in data passed to ComplementNB (input X)

# %% [markdown]
# #### Bernoulli Naive Bayes

# %%
# Instantiate Classifier
bnb_doc = BernoulliNB()
# Fit to training data
bnb_doc.fit(doc_train_df, y_train_doc)
# Predict on testing data
bnb_doc_preds = bnb_doc.predict(doc_test_df)
# Evaluating with classification report
print(classification_report(y_test_doc, bnb_doc_preds))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.43      0.36      0.40       785
#          man       0.64      0.74      0.68      4529
#      neutral       0.36      0.27      0.31      1562
#         news       0.51      0.45      0.48      1907
#
#     accuracy                           0.56      8783
#    macro avg       0.49      0.46      0.47      8783
# weighted avg       0.54      0.56      0.55      8783

# %% [markdown]
# ### With Features Added

# %% [markdown]
# #### Random Forest

# %%
# Instantiate Classifier
rf_doc_featured = RandomForestClassifier()
# Fit to training data
rf_doc_featured.fit(doc_train_featured, y_train_doc)
# Predict on testing data
rf_doc_preds_featured = rf_doc_featured.predict(doc_test_featured)
# Evaluating with classification report
print(classification_report(y_test_doc, rf_doc_preds_featured))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.64      0.39      0.48       785
#          man       0.70      0.85      0.77      4529
#      neutral       0.55      0.43      0.48      1562
#         news       0.74      0.64      0.69      1907
#
#     accuracy                           0.69      8783
#    macro avg       0.66      0.58      0.61      8783
# weighted avg       0.68      0.69      0.68      8783

# %% [markdown]
# #### SVM

# %% [markdown]
# #### Logistic Regression

# %%
# Instantiate Classifier
lr_doc_featured = LogisticRegression()
# Fit to training data
lr_doc_featured.fit(doc_train_featured, y_train_doc)
# Predict on testing data
lr_doc_preds_featured = lr_doc_featured.predict(doc_test_featured)
# Evaluating with classification report
print(classification_report(y_test_doc, lr_doc_preds_featured))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.55      0.41      0.47       785
#          man       0.70      0.80      0.75      4529
#      neutral       0.49      0.38      0.43      1562
#         news       0.67      0.65      0.66      1907
#
#     accuracy                           0.66      8783
#    macro avg       0.60      0.56      0.58      8783
# weighted avg       0.64      0.66      0.65      8783

# %% [markdown]
# #### Multinomial Naive Bayes

# %%
# Instantiate Classifier
mnb_doc = MultinomialNB()
# Fit to training data
mnb_doc.fit(doc_train_featured, y_train_doc)
# Predict on testing data
mnb_doc_preds = mnb_doc.predict(doc_test_featured)
# Evaluating with classification report
print(classification_report(y_test_doc, mnb_doc_preds))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-e63f57d6939d> in <module>
#       2 mnb_doc = MultinomialNB()
#       3 # Fit to training data
# ----> 4 mnb_doc.fit(doc_train_df, y_train_doc)
#       5 # Predict on testing data
#       6 mnb_doc_preds = mnb_doc.predict(doc_test_df)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     639
#     640         self._init_counters(n_effective_classes, n_features)
# --> 641         self._count(X, Y)
#     642         alpha = self._check_alpha()
#     643         self._update_feature_log_prob(alpha)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/naive_bayes.py in _count(self, X, Y)
#     761     def _count(self, X, Y):
#     762         """Count and smooth feature occurrences."""
# --> 763         check_non_negative(X, "MultinomialNB (input X)")
#     764         self.feature_count_ += safe_sparse_dot(Y.T, X)
#     765         self.class_count_ += Y.sum(axis=0)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/validation.py in check_non_negative(X, whom)
#    1044
#    1045     if X_min < 0:
# -> 1046         raise ValueError("Negative values in data passed to %s" % whom)
#    1047
#    1048
#
# ValueError: Negative values in data passed to MultinomialNB (input X)

# %% [markdown]
# #### Complement Naive Bayes

# %%
# Instantiate Classifier
cnb_doc = ComplementNB()
# Fit to training data
cnb_doc.fit(doc_train_featured, y_train_doc)
# Predict on testing data
cnb_doc_preds = cnb_doc.predict(doc_test_featured)
# Evaluating with classification report
print(classification_report(y_test_doc, cnb_doc_preds))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-6358c57b8d0a> in <module>
#       2 cnb_doc = ComplementNB()
#       3 # Fit to training data
# ----> 4 cnb_doc.fit(doc_train_df, y_train_doc)
#       5 # Predict on testing data
#       6 cnb_doc_preds = cnb_doc.predict(doc_test_df)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     639
#     640         self._init_counters(n_effective_classes, n_features)
# --> 641         self._count(X, Y)
#     642         alpha = self._check_alpha()
#     643         self._update_feature_log_prob(alpha)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/naive_bayes.py in _count(self, X, Y)
#     868     def _count(self, X, Y):
#     869         """Count feature occurrences."""
# --> 870         check_non_negative(X, "ComplementNB (input X)")
#     871         self.feature_count_ += safe_sparse_dot(Y.T, X)
#     872         self.class_count_ += Y.sum(axis=0)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/validation.py in check_non_negative(X, whom)
#    1044
#    1045     if X_min < 0:
# -> 1046         raise ValueError("Negative values in data passed to %s" % whom)
#    1047
#    1048
#
# ValueError: Negative values in data passed to ComplementNB (input X)

# %% [markdown]
# #### Bernoulli Naive Bayes

# %%
# Instantiate Classifier
bnb_doc_featured = BernoulliNB()
# Fit to training data
bnb_doc_featured.fit(doc_train_featured, y_train_doc)
# Predict on testing data
bnb_doc_preds_featured = bnb_doc_featured.predict(doc_test_featured)
# Evaluating with classification report
print(classification_report(y_test_doc, bnb_doc_preds_featured))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.47      0.31      0.38       785
#          man       0.66      0.69      0.68      4529
#      neutral       0.41      0.38      0.40      1562
#         news       0.55      0.60      0.57      1907
#
#     accuracy                           0.58      8783
#    macro avg       0.52      0.50      0.51      8783
# weighted avg       0.58      0.58      0.58      8783

# %% [markdown]
# # Choosing Best Model

# %% [markdown]
# ## Modeling with TFIDF

# %% [markdown]
# ### Random Forest

# %%
# Instantiate Classifier
rf_tfidf = RandomForestClassifier()
# Fit to training data
rf_tfidf.fit(tfidf_train_df, y_train)
# Predict on testing data
rf_tfidf_preds = rf_tfidf.predict(tfidf_test_df)
# Evaluating with classification report
print(classification_report(y_test, rf_tfidf_preds))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.78      0.27      0.40       823
#            0       0.49      0.48      0.49      1549
#            1       0.70      0.82      0.75      4526
#            2       0.70      0.61      0.65      1885
#
#     accuracy                           0.66      8783
#    macro avg       0.67      0.54      0.57      8783
# weighted avg       0.67      0.66      0.65      8783

# %% [markdown]
# ### SVM

# %%
# # Instantiate Classifier
# svm_tfidf = svm.SVC()
# # Fit to training data
# svm_tfidf.fit(tfidf_train_df, y_train)
# # Predict on testing data
# svm_tfidf_preds = svm_tfidf.predict(tfidf_test_df)
# # Evaluating with classification report
# print(classification_report(y_test, svm_tfidf_preds))

# %% [markdown]
# ### Multinomial Naive Bayes

# %%
# Instantiate Classifier
mnb_tfidf = MultinomialNB()
# Fit to training data
mnb_tfidf.fit(tfidf_train_df, y_train)
# Predict on testing data
mnb_tfidf_preds = mnb_tfidf.predict(tfidf_test_df)
# Evaluating with classification report
print(classification_report(y_test, mnb_tfidf_preds))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.97      0.05      0.09       823
#            0       0.97      0.07      0.13      1549
#            1       0.57      0.99      0.72      4526
#            2       0.87      0.36      0.51      1885
#
#     accuracy                           0.60      8783
#    macro avg       0.85      0.36      0.36      8783
# weighted avg       0.74      0.60      0.51      8783

# %% [markdown]
# ### Logistic Regression

# %%
# Instantiate Classifier
lr_tfidf = LogisticRegression()
# Fit to training data
lr_tfidf.fit(tfidf_train_df, y_train)
# Predict on testing data
lr_tfidf_preds = lr_tfidf.predict(tfidf_test_df)
# Evaluating with classification report
print(classification_report(y_test, lr_tfidf_preds))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.76      0.39      0.52       823
#            0       0.64      0.40      0.49      1549
#            1       0.71      0.88      0.79      4526
#            2       0.73      0.67      0.70      1885
#
#     accuracy                           0.71      8783
#    macro avg       0.71      0.59      0.62      8783
# weighted avg       0.71      0.71      0.69      8783

# %% [markdown]
# #### Confusion Matrix

# %%
# Setting class names for confusion matrix
class_names = ['Anti Man-Made', 'Neutral', 'Man-Made', 'News']

# Plot confusion matrix
plt.figure(figsize=(20,10))
titles_options = [("TFIDF Logistic Regression Confusion Matrix", None),
                  ("TFIDF Logistic Regression Confusion Matrix (Normalized)", 'true')]
for title, normalize in titles_options:
    disp = plot_confusion_matrix(lr_tfidf, tfidf_test_df, y_test,
                                 display_labels=class_names,
                                 cmap=plt.cm.Blues,
                                 normalize=normalize)
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)

plt.show()
# Out:
# TFIDF Logistic Regression Confusion Matrix
# [[ 324  116  327   56]
#  [  45  618  758  128]
#  [  42  187 4000  297]
#  [  17   40  556 1272]]
# TFIDF Logistic Regression Confusion Matrix (Normalized)
# [[0.39368165 0.14094775 0.39732685 0.06804374]
#  [0.029051   0.39896708 0.48934797 0.08263396]
#  [0.00927972 0.04131684 0.88378259 0.06562086]
#  [0.00901857 0.02122016 0.29496021 0.67480106]]

# %% [markdown]
# #### Feature Importance

# %%
# lr_tfidf.

# %%
# coefs = np.abs(lr_tfidf.coef_[0])
# indices = np.argsort(coefs)[::-1]

# plt.figure()
# plt.title("Feature importances TFIDF Logistic Regression")
# plt.bar(range(10), coefs[indices[:10]],
#        color="r", align="center")
# plt.xticks(range(10), indices[:10], rotation=45, ha='right')
# plt.subplots_adjust(bottom=0.3)

# %% [markdown]
# ### KNN

# %%
# Instantiate Classifier
knn_tfidf = KNeighborsClassifier()
# Fit to training data
knn_tfidf.fit(tfidf_train_df, y_train)
# Predict on testing data
knn_tfidf_preds = knn_tfidf.predict(tfidf_test_df)
# Evaluating with classification report
print(classification_report(y_test, knn_tfidf_preds))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.46      0.39      0.42       823
#            0       0.41      0.49      0.45      1549
#            1       0.70      0.70      0.70      4526
#            2       0.61      0.54      0.57      1885
#
#     accuracy                           0.60      8783
#    macro avg       0.54      0.53      0.53      8783
# weighted avg       0.61      0.60      0.60      8783

# %% [markdown]
# ## TFIDF Features Added

# %%
# Combining tfidf with custom features
tfidf_train_featured = pd.concat([X_train, tfidf_train_df], 
                          axis=1)
tfidf_test_featured = pd.concat([X_test, tfidf_test_df], 
                         axis=1)

# %% [markdown]
# ### Random Forest

# %%
# # Instantiate Classifier
# rf_tfidf_featured = RandomForestClassifier()
# # Fit to training data
# rf_tfidf_featured.fit(tfidf_train_featured, y_train)
# # Predict on testing data
# rf_tfidf_featured_preds = rf_tfidf_featured.predict(tfidf_test_featured)
# # Evaluating with classification report
# print(classification_report(y_test, rf_tfidf_featured_preds))

# %% [markdown]
# ### SVM

# %%
# # Instantiate Classifier
# svm_tfidf_featured = svm.SVC()
# # Fit to training data
# svm_tfidf_featured.fit(tfidf_train_featured, y_train)
# # Predict on testing data
# svm_tfidf_featured_preds = svm_tfidf_featured.predict(tfidf_test_featured)
# # Evaluating with classification report
# print(classification_report(y_test, svm_tfidf_featured_preds))

# %% [markdown]
# ### Multinomial Naive Bayes

# %%
# # Instantiate Classifier
# mnb_tfidf_featured = MultinomialNB()
# # Fit to training data
# mnb_tfidf_featured.fit(tfidf_train_featured, y_train)
# # Predict on testing data
# mnb_tfidf_featured_preds = mnb_tfidf_featured.predict(tfidf_test_featured)
# # Evaluating with classification report
# print(classification_report(y_test, mnb_tfidf_featured_preds))

# %% [markdown]
# ### Logistic Regression

# %%
# # Instantiate Classifier
# lr_tfidf_featured = LogisticRegression()
# # Fit to training data
# lr_tfidf_featured.fit(tfidf_train_featured, y_train)
# # Predict on testing data
# lr_tfidf_featured_preds = lr_tfidf_featured.predict(tfidf_test_featured)
# # Evaluating with classification report
# print(classification_report(y_test, lr_tfidf_featured_preds))

# %% [markdown]
# ### KNN

# %%
# # Instantiate Classifier
# knn_tfidf_featured = KNeighborsClassifier()
# # Fit to training data
# knn_tfidf_featured.fit(tfidf_train_featured, y_train)
# # Predict on testing data
# knn_tfidf_featured_preds = knn_tfidf_featured.predict(tfidf_test_featured)
# # Evaluating with classification report
# print(classification_report(y_test, knn_tfidf_featured_preds))

# %% [markdown]
# ## Modeling with Doc2Vec

# %% [markdown]
# ### Data Prep

# %%
data = pd.read_csv('./data_collection/prepared_twitter_sentiment_data.csv', index_col=0)

# %%
# Drop 31 rows with missing values in message column
data.dropna(inplace=True)

# %%
# Reassigning target variable names to exclude -1
data.sentiment = data.sentiment.apply(lambda x: 'anti' if x == -1 else x)
data.sentiment = data.sentiment.apply(lambda x: 'neutral' if x == 0 else x)
data.sentiment = data.sentiment.apply(lambda x: 'man' if x == 1 else x)
data.sentiment = data.sentiment.apply(lambda x: 'news' if x == 2 else x)

# %%
# Performing train test split including target variable
train, test = train_test_split(data, test_size=0.2, random_state=42)

# %%
# Separating target variables from train and test
y_train_doc = train.sentiment
y_test_doc = test.sentiment

# %%
# Tokenizing and tagging each observation message column
train_docs = train.apply(lambda x: TaggedDocument(words=x.message.split(), tags=[x.sentiment]), axis=1)

# %%
# Tokenizing train and test data
train_data = [tweet.split() for tweet in train['message']]
test_data = [tweet.split() for tweet in test['message']]

# %%
# %%time

# training Doc2Vec
model = Doc2Vec(vector_size=100, 
                alpha=0.025, 
                min_count=5,
                dm=1, epochs=100)

model.build_vocab(train_docs)
model.train(train_docs, 
            total_examples=model.corpus_count, 
            epochs=model.epochs)
# Out:
# CPU times: user 3min 1s, sys: 31 s, total: 3min 32s
# Wall time: 2min 45s

# %%
# %%time

# infer in multiple steps to get a stable representation 
train_vecs = [model.infer_vector(words, epochs=100) \
              for words in train_data]
test_vecs = [model.infer_vector(words, epochs=100) \
             for words in test_data]
# Out:
# CPU times: user 2min 26s, sys: 826 ms, total: 2min 27s
# Wall time: 2min 29s

# %%
# %%time

# convert both sets to dataframe
doc_train_df = pd.DataFrame(train_vecs, columns=[
    f'docvec_{i}' for i in range(1,101)
])

doc_test_df = pd.DataFrame(test_vecs, columns=[
    f'docvec_{i}' for i in range(1,101)
])
# Out:
# CPU times: user 1.62 s, sys: 101 ms, total: 1.72 s
# Wall time: 1.73 s

# %% [markdown]
# ### Random Forest

# %%
rf_doc = RandomForestClassifier()

rf_doc.fit(doc_train_df, y_train_doc)
rf_doc_preds = rf_doc.predict(doc_test_df)
print(classification_report(y_test, rf_doc_preds))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.37      0.16      0.22       785
#          man       0.57      0.85      0.68      4529
#      neutral       0.40      0.32      0.35      1562
#         news       0.71      0.19      0.29      1907
#
#     accuracy                           0.55      8783
#    macro avg       0.51      0.38      0.39      8783
# weighted avg       0.55      0.55      0.50      8783

# %% [markdown]
# ### SVM

# %%
svm_doc = svm.SVC()

svm_doc.fit(doc_train_df, y_train_doc)
svm_doc_preds = svm_doc.predict(doc_test_df)
print(classification_report(y_test, svm_doc_preds))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.30      0.45      0.36       785
#          man       0.64      0.79      0.71      4529
#      neutral       0.42      0.36      0.39      1562
#         news       0.77      0.29      0.42      1907
#
#     accuracy                           0.57      8783
#    macro avg       0.53      0.47      0.47      8783
# weighted avg       0.60      0.57      0.56      8783

# %% [markdown]
# ### Multinomial Naive Bayes

# %%
# mnb_doc = MultinomialNB()

# mnb_doc.fit(doc_train_df, y_train_doc)
# mnb_doc_preds = mnb_doc.predict(doc_test_df)
# print(classification_report(y_test, mnb_doc_preds))

# %% [markdown]
# ### Logistic Regression

# %%
lr_doc = LogisticRegression()

lr_doc.fit(doc_train_df, y_train_doc)
lr_doc_preds = lr_doc.predict(doc_test_df)
print(classification_report(y_test, lr_doc_preds))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.28      0.47      0.35       785
#          man       0.68      0.59      0.63      4529
#      neutral       0.37      0.44      0.40      1562
#         news       0.49      0.44      0.46      1907
#
#     accuracy                           0.52      8783
#    macro avg       0.45      0.48      0.46      8783
# weighted avg       0.55      0.52      0.53      8783

# %% [markdown]
# ### KNN

# %%
knn_doc = KNeighborsClassifier()

knn_doc.fit(doc_train_df, y_train_doc)
knn_doc_preds = knn_doc.predict(doc_test_df)
print(classification_report(y_test, knn_doc_preds))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.34      0.34      0.34       785
#          man       0.65      0.73      0.69      4529
#      neutral       0.40      0.42      0.41      1562
#         news       0.65      0.42      0.51      1907
#
#     accuracy                           0.57      8783
#    macro avg       0.51      0.48      0.49      8783
# weighted avg       0.58      0.57      0.57      8783

# %% [markdown]
# ## Doc2Vec Features Added

# %%
# Extracting just features from dataframe
train_features = train.drop(columns=['sentiment','message'])
test_features = test.drop(columns=['sentiment','message'])

# Reset index to match doc2vec dataframe
train_features.reset_index(drop=True, inplace=True)
test_features.reset_index(drop=True, inplace=True)

# %%
# Combining Doc2Vec with custom features
doc_train_featured = doc_train_df.join(train_features, how='outer')
doc_test_featured = doc_test_df.join(test_features, how='outer')

# %% [markdown]
# ### Random Forest

# %%
rf_doc_featured = RandomForestClassifier()

rf_doc_featured.fit(doc_train_featured, y_train_doc)
rf_doc_featured_preds = rf_doc_featured.predict(doc_test_featured)
print(classification_report(y_test_doc, rf_doc_featured_preds))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.34      0.19      0.24       785
#          man       0.60      0.84      0.70      4529
#      neutral       0.47      0.34      0.39      1562
#         news       0.75      0.36      0.49      1907
#
#     accuracy                           0.59      8783
#    macro avg       0.54      0.43      0.46      8783
# weighted avg       0.59      0.59      0.56      8783

# %% [markdown]
# #### Confusion Matrix

# %%
# Plot non-normalized confusion matrix
titles_options = [("Doc2Vec (with Features) Random Forest Confusion Matrix", None),
                  ("Doc2Vec (with Features) Random Forest Confusion Matrix (Normalized)", 'true')]
for title, normalize in titles_options:
    disp = plot_confusion_matrix(rf_doc_featured, doc_test_featured, y_test_doc,
                                 display_labels=class_names,
                                 cmap=plt.cm.Blues,
                                 normalize=normalize)
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)

plt.show()
# Out:
# Doc2Vec (with Features) Random Forest Confusion Matrix
# [[ 150  489  106   40]
#  [ 188 3800  405  136]
#  [  82  898  524   58]
#  [  21 1121   79  686]]
# Doc2Vec (with Features) Random Forest Confusion Matrix (Normalized)
# [[0.1910828  0.62292994 0.13503185 0.05095541]
#  [0.04151027 0.83903732 0.08942371 0.0300287 ]
#  [0.0524968  0.57490397 0.33546735 0.03713188]
#  [0.01101206 0.58783429 0.04142632 0.35972732]]

# %% [markdown]
# #### Feature Importance

# %%
# Getting to this

# %% [markdown]
# ### SVM

# %%
# svm_doc_featured = svm.SVC()

# svm_doc_featured.fit(doc_train_featured, y_train_doc)
# svm_doc_featured_preds = svm_doc_featured.predict(doc_test_featured)
# print(classification_report(y_test_doc, svm_doc_featured_preds))

# %% [markdown]
# ### Multinomial Naive Bayes

# %%
# mnb_doc_featured = MultinomialNB()

# mnb_doc_featured.fit(doc_train_featured, y_train_doc)
# mnb_doc_featured_preds = mnb_doc_featured.predict(doc_test_featured)
# print(classification_report(y_test_doc, mnb_doc_featured_preds))

# %% [markdown]
# ### Logistic Regression

# %%
lr_doc_featured = LogisticRegression()

lr_doc_featured.fit(doc_train_featured, y_train_doc)
lr_doc_featured_preds = lr_doc_featured.predict(doc_test_featured)
print(classification_report(y_test_doc, lr_doc_featured_preds))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.36      0.34      0.35       785
#          man       0.70      0.68      0.69      4529
#      neutral       0.42      0.42      0.42      1562
#         news       0.53      0.57      0.55      1907
#
#     accuracy                           0.58      8783
#    macro avg       0.50      0.50      0.50      8783
# weighted avg       0.58      0.58      0.58      8783

# %% [markdown]
# ### KNN

# %%
knn_doc_featured = KNeighborsClassifier()

knn_doc_featured.fit(doc_train_featured, y_train_doc)
knn_doc_featured_preds = knn_doc_featured.predict(doc_test_featured)
print(classification_report(y_test_doc, knn_doc_featured_preds))
# Out:
#               precision    recall  f1-score   support
#
#         anti       0.30      0.17      0.22       785
#          man       0.62      0.75      0.68      4529
#      neutral       0.44      0.30      0.36      1562
#         news       0.52      0.50      0.51      1907
#
#     accuracy                           0.56      8783
#    macro avg       0.47      0.43      0.44      8783
# weighted avg       0.54      0.56      0.55      8783

# %% [markdown]
# # TFIDF Logistic Regression Parameter Tuning

# %%
# Setting searching parameters for RandomSearch
param_grid = {
    'penalty': ['l1','l2'],
    'C': np.logspace(-4,4,20),
    'solver': ['lbfgs','liblinear']
}

# %%
# Instantiate Classifier
lr_final = LogisticRegression(random_state=42)
# Instantiate GridSearch
rand_lr_final = RandomizedSearchCV(lr_final, 
                                   param_grid, 
                                   n_jobs=-1,
                                   verbose=2,
                                   scoring='f1_micro')

# %%
# Fit grid_lr_final to training data
rand_lr_final.fit(tfidf_train_df, y_train)
# Predict on testing data
rand_lr_final_preds = rand_lr_final.predict(tfidf_test_df)
# Evaluating with classification report
print(classification_report(y_test, rand_lr_final_preds))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed: 126.0min
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed: 171.1min finished
#               precision    recall  f1-score   support
#
#           -1       0.68      0.53      0.59       823
#            0       0.65      0.40      0.50      1549
#            1       0.74      0.86      0.79      4526
#            2       0.72      0.73      0.72      1885
#
#     accuracy                           0.72      8783
#    macro avg       0.70      0.63      0.65      8783
# weighted avg       0.71      0.72      0.71      8783

# %%
rand_lr_final.best_params_
# Out:
# {'solver': 'liblinear', 'penalty': 'l2', 'C': 78.47599703514607}

# %%
param_grid_2 = {
    'C': [70, 75, 80, 85, 90],
}

# %%
# Instantiate Classifier
lr_final_2 = LogisticRegression(solver = 'liblinear', penalty = 'l2', random_state=42)
# Instantiate GridSearch
rand_lr_final_2 = RandomizedSearchCV(lr_final_2, 
                                   param_grid_2, 
                                   n_jobs=-1,
                                   verbose=2,
                                   scoring='f1_micro',
                                   cv = 5)

# %%
# Fit grid_lr_final to training data
rand_lr_final_2.fit(tfidf_train_df, y_train)
# Predict on testing data
rand_lr_final_preds_2 = rand_lr_final_2.predict(tfidf_test_df)
# Evaluating with classification report
print(classification_report(y_test, rand_lr_final_preds_2))
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed: 125.6min finished
#               precision    recall  f1-score   support
#
#           -1       0.68      0.53      0.59       823
#            0       0.65      0.40      0.50      1549
#            1       0.74      0.86      0.79      4526
#            2       0.72      0.73      0.72      1885
#
#     accuracy                           0.72      8783
#    macro avg       0.70      0.63      0.65      8783
# weighted avg       0.71      0.72      0.71      8783

# %%
rand_lr_final_2.best_params_
# Out:
# {'C': 70}

# %%
param_grid_3 = {
    'max_iter': [100, 200, 300],
}

# %%
# Instantiate Classifier
lr_final_3 = LogisticRegression(C = 70, 
                                penalty = 'l2', 
                                random_state=42, 
                                class_weight='balanced')
# Instantiate GridSearch
rand_lr_final_3 = RandomizedSearchCV(lr_final_3, 
                                   param_grid_3, 
                                   n_jobs=-1,
                                   verbose=2,
                                   scoring='f1_micro',
                                   cv = 5)

# %%
# Fit grid_lr_final to training data
rand_lr_final_3.fit(tfidf_train_df, y_train)
# Predict on testing data
rand_lr_final_preds_3 = rand_lr_final_3.predict(tfidf_test_df)
# Evaluating with classification report
print(classification_report(y_test, rand_lr_final_preds_3))
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed: 61.7min finished
#               precision    recall  f1-score   support
#
#           -1       0.61      0.62      0.61       823
#            0       0.61      0.46      0.52      1549
#            1       0.77      0.81      0.79      4526
#            2       0.70      0.75      0.73      1885
#
#     accuracy                           0.72      8783
#    macro avg       0.67      0.66      0.66      8783
# weighted avg       0.71      0.72      0.71      8783

# %%
rand_lr_final_3.best_estimator_
# Out:
# LogisticRegression(C=70, class_weight='balanced', max_iter=300, random_state=42)

# %%
# Plot non-normalized confusion matrix
titles_options = [("Hyperparameter Tuned TFIDF Logistic Regression Confusion Matrix", None),
                  ("Hyperparameter Tuned TFIDF Logistic Regression Confusion Matrix (Normalized)", 'true')]
for title, normalize in titles_options:
    disp = plot_confusion_matrix(rand_lr_final_3, tfidf_test_df, y_test,
                                 display_labels=class_names,
                                 cmap=plt.cm.Blues,
                                 normalize=normalize)
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)

plt.show()
# Out:
# Hyperparameter Tuned TFIDF Logistic Regression Confusion Matrix
# [[ 509   97  180   37]
#  [ 151  711  535  152]
#  [ 143  299 3669  415]
#  [  34   68  360 1423]]
# Hyperparameter Tuned TFIDF Logistic Regression Confusion Matrix (Normalized)
# [[0.61846902 0.11786148 0.21871203 0.04495747]
#  [0.09748225 0.45900581 0.34538412 0.09812782]
#  [0.03159523 0.06606275 0.81064958 0.09169244]
#  [0.01803714 0.03607427 0.19098143 0.75490716]]

# %% [markdown]
# # Pickling Best Model

# %% [markdown]
# ## Training on Whole Dataset

# %%
data = pd.read_csv('./data_collection/prepared_twitter_sentiment_data.csv', index_col=0)

# Drop 31 rows with missing message column
data.dropna(inplace=True)

# %%
# Instantiate vectorizer
tfidf = TfidfVectorizer(ngram_range= (1,1))
# Fit to training data
tfidf_whole = tfidf.fit_transform(data.message)

# %%
pickle_vec = open("tfidf.pickle","wb")
pickle.dump(tfidf_whole, pickle_vec)
pickle_vec.close()

# %%
tfidf_whole
# Out:
# <43912x26067 sparse matrix of type '<class 'numpy.float64'>'
# 	with 409576 stored elements in Compressed Sparse Row format>

# %%
# Convert vectors to dataframe
tfidf_whole_df = pd.DataFrame.sparse.from_spmatrix(
    tfidf_whole, columns=tfidf.get_feature_names())

# %%
best_overall_model = LogisticRegression(C=70, class_weight='balanced', max_iter=300, random_state=42)

best_overall_model.fit(tfidf_whole_df, data.sentiment)
# Out:
# LogisticRegression(C=70, class_weight='balanced', max_iter=300, random_state=42)

# %% [markdown]
# ### Pickling Model

# %%
import pickle

# %%
pickle_out = open("best_model.pickle","wb")
pickle.dump(best_overall_model, pickle_out)
pickle_out.close()
